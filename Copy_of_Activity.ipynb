# %% [markdown]
# <a href="https://colab.research.google.com/github/mclaris/Monte-Carlo-Simulation/blob/main/Copy_of_Activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Activity for Web Scraping using BeautifulSoup**
#
#
# **Instruction**
#
# Choose a **genre** from [Books to Scrape](https://books.toscrape.com/)—such as Mystery, Historical Fiction, Science Fiction, Romance, Fantasy, Horror, Poetry, Thriller, Business, Biography, and more—then scrape the following details for each book in that genre and save the data to a CSV file:
#
# 📌 **Filename Format**: StudentNumber_ACTIVITY_Genre
#
#      Example: 2024-12345-MN-0_ACTIVITY_Genre
#
# 📌 **Data to Scrape**:
# *   Title
# *   Price
# *   Rating
#
# Ensure the scraped data is well-structured and formatted correctly for easy analysis.
#
# Example output:
# ![book.PNG](data:image/png;base64,...)
